# %% [markdown]
# ### Práctica de Formatos de datos: CSV y JSON

# %% [markdown]
# #### Ejercicio 1[5 puntos]
# Considerar los archivos __Terrazas.csv__ y __Locales.csv__ que contiene un censo de locales y actividades del Ayuntamiento de Madrid, clasificados según su tipo de acceso (puerta de calle o agrupado), situación (abierto, cerrado...) e indicación de la actividad económica ejercida y de las terrazas de hostelería y restauración que aparecen registradas en dicho censo. Observar que la información puede contener alguna inconsistencia.Se pide realizar funciones en Python que permitan realizar las siguientes acciones:
#
# * Usando los dos archivos indicados, se pide crear un nuevo archivo csv denominados __NoTerrazas.csv__ el cual contenga la información de los locales que no son terrazas. Es decir, contendrá la misma información que el archivo __Locales.csv__ pero sin la información de locales que son Terrazas.
#
# * Usando el archivo __Locales.csv__ se pide crear una nuevo archivo csv denominada __Agrupadas.csv__ el cual debe contener una línea por cada barrio conteniendo el número de locales en los que el nombre del vial del edificio en que se encuentran es diferente del nombre del vial de acceso al local. Por ejemplo el local con id 10000401 se encuentra en la Plaza de Isabel II pero el acceso al mismo se realiza desde la Calle Arenal. La información en el archivo debe aparecer en el siguiente orden:
#
#   Código Barrio, Nombre Barrio, Número de empresas cumpliendo la condición
#
#
#
# * Usando el archivo __Terrazas.csv__ crea un nuevo archivo cvs denominado TopRepeticiones.cvs. Considera el número de veces que se repite el nombre de una terraza (campo rótulo). Se pide crear un archivo csv que contenga los 20 nombres que más se repiten. La información en el archivo debe aparecer en orden descendente con los siguientes campos de información:
#
#   Nombre terraza, Número de repeticiones

# %% [markdown]
# Para leer los archivos usa un código como el siguiente:

# %% [raw]
# import csv
# csvarchivo = open('Locales.csv',encoding="utf8",errors='ignore')
# entrada = csv.reader(csvarchivo, delimiter=";")

# %%
import csv


"""Usando los dos archivos indicados, se pide crear un nuevo archivo csv denominados NoTerrazas.csv 
el cual contenga la información de los locales que no son terrazas. Es decir, contendrá la misma
información que el archivo Locales.csv pero sin la información de locales que son Terrazas."""

def foo_1():
    csvarchivo = open('Locales.csv',encoding="utf8",errors='ignore')
    entrada = list(csv.reader(csvarchivo, delimiter=";"))
    csvarchivo.close()
    
    de = open('Terrazas.csv',encoding="utf8",errors='ignore')
    entrada2 = list(csv.reader(de, delimiter=";"))
    de.close()
    
    salida = open('NoTerrazas.csv', "w", encoding="utf8",errors='ignore')
    buffer_salida = csv.writer(salida)
    buffer_salida.writerow(entrada[0])
    
    
    for i in entrada[1:]:
        for j in entrada2[1:]:
            if i[0] == j[0]:
                break
        buffer_salida.writerow(i)
        print(i)
    print("done!!")
    salida.close()
    return

# %%
import csv

"""Usando el archivo Locales.csv se pide crear una nuevo archivo csv denominada Agrupadas.csv 
el cual debe contener una línea por cada barrio, conteniendo el número de locales en los que el
nombre del vial del edificio en que se encuentran es diferente del nombre del vial de acceso al local. 
Por ejemplo el local con id 10000401 se encuentra en la Plaza de Isabel II pero el acceso al mismo 
se realiza desde la Calle Arenal. 
La información en el archivo debe aparecer en el siguiente orden
    Código Barrio, Nombre Barrio, Número de empresas cumpliendo la condición
"""

def foo_2():
    csvarchivo = open('Locales.csv',encoding="utf8",errors='ignore')
    entrada = list(csv.reader(csvarchivo, delimiter=";"))
    csvarchivo.close()
    
    agrupadas = open('Agrupadas.csv', "w", encoding="utf8", errors='ignore')
    buffer_agrupadas = csv.writer(agrupadas)
    index = 0

    # Algoritmo aparenetemente lineal a falta de ver los tiempos de los diccionarios
    dic = {}
    for i in entrada[1:]:
        chain1 = i[15] + i[16]
        chain2 = i[24] + i[25]
        if chain1 != chain2:
            print(i[3],i[15].rstrip(),i[16].rstrip(),i[24].rstrip(),i[25].rstrip(), i[4].rstrip())
            try:
                name, value = dic.pop(i[3])
                dic.setdefault(i[3], (i[4].rstrip(), value + 1))
            except Exception:
                dic.setdefault(i[3], (i[4].rstrip(), 1))
    for key in dic:
        print(key, dic.get(key))

# %%
import csv

"""Usando el archivo __Terrazas.csv__ crea un nuevo archivo cvs denominado TopRepeticiones.cvs. 
Considera el número de veces que se repite el nombre de una terraza (campo rótulo). 
Se pide crear un archivo csv que contenga los 20 nombres que más se repiten. 
La información en el archivo debe aparecer en orden descendente con los siguientes campos 
de información: Nombre terraza, Número de repeticiones
"""

def foo_3():
    csvarchivo = open('Terrazas.csv',encoding="utf8",errors='ignore')
    entrada = list(csv.reader(csvarchivo, delimiter=";"))
    csvarchivo.close()
    
    agrupadas = open('TopRepeticiones.csv', "w", encoding="utf8", errors='ignore')
    buffer_agrupadas = csv.writer(agrupadas)
    
    """index = 0
    for i in entrada[0]:
        print(index, i)
        index += 1"""
        
    dic = {}
    for i in entrada[1:]:
        try:
            value = dic.pop(i[21])
            dic.setdefault(i[21], (value + 1))
        except Exception:
            dic.setdefault(i[21], 1)
    lista_terrazas = sorted(dic.items(), key = lambda select: select[1], reverse = True)
    
    for (i, j) in lista_terrazas[:20]:
        print(j, i)

# %%
foo_3()
# Out:
# 82 RÓTULO NO INFORMADO
# 41 BAR
# 23 RODILLA
# 17 LIZARRAN
# 17 VIPS
# 15 100 MONTADITOS
# 12 BAR RESTAURANTE
# 12 BAR-RESTAURANTE
# 11 CERVECERIA 100 MONTADITOS
# 11 CAFETERIA
# 10 SR
# 10 NO SOLICITADO
# 9 BURGER KING
# 8 GINOS
# 8 STARBUCKS COFFEE
# 8 RESTAURANTE
# 7 TELEPIZZA
# 7 VIENA CAPELLANES
# 6 FABORIT
# 6 MERCADO PROVENZAL

# %% [markdown]
# #### Ejercicio 2[5 puntos]
# Considerar el archivo __Agenda.json__ que contiene información de actividades de carácter gratuito, para público infantil y adulto, desarrolladas por las siguientes instituciones de titularidad municipal: la red de Bibliotecas Públicas, la Biblioteca Histórica, la Biblioteca Musical Víctor Espinós, la Hemeroteca y la Imprenta. Se presentan las actividades de los próximos 60 dias. Se pide realizar funciones en Python que permitan realizar las siguientes acciones:
#
# * El archivo contiene un campo denominado "audience" que indica el público al que va dirigido. A veces aparece y otras veces no aparece dicho campo. Se quiere procesar el archivo para obtener como resultado dos archivos de texto:el archivo __Niños.txt__ que contendrá la información de los eventos que es exclusivamente para niños y el archivo __Familias.txt__ que contendrá la información de los eventos que está dirigida a niños y familias. En los archivos debe aparecer una línea por cada evento cumpliendo las condiciones indicadas, y mostrando la información siguiente:
#
#    Título del evento(campo title), inicio(campo "dtstart"), finalizacion(campo "dtend"), url(campo link)
#
#
# * Se desea conocer los eventos más cercanos a un punto que viene especificado por su longitud y latitud. De manera que se quiere crear una función que tomando como entrada una longitud, una latitud y un número real que representa una distancia en kilometros, devuelva como resultado los eventos que se encuentran a una distancia menor o igual a la distancia dada como parámetro. El resultado se mostrará por la pantalla mostrando una línea por cada evento. De cada evento se mostrará:
#
#   Título del evento(campo title), inicio(campo "dtstart"), finalizacion(campo "dtend"), url(campo link)
#
# Para calcular la distancia entre dos puntos dadas sus coordenadas se utilizará la siguiente función en Python:

# %%
"""
El archivo contiene un campo denominado "audience" que indica el público al que va dirigido.
A veces aparece y otras veces no aparece dicho campo. Se quiere procesar el archivo para obtener 
como resultado dos archivos de texto:el archivo __Niños.txt__ que contendrá la información de los
eventos que es exclusivamente para niños y el archivo __Familias.txt__ que contendrá la información
de los eventos que está dirigida a niños y familias. En los archivos debe aparecer una línea por cada 
evento cumpliendo las condiciones indicadas, y mostrando la información siguiente:
    Título del evento(campo title), inicio(campo "dtstart"), finalizacion(campo "dtend"), url(campo link)
"""

import json
leer = json.loads(open('Agenda.json',encoding="utf8").read())

ninios = open("Niños.txt", "w")
familias = open("Familias.txt", "w")

for i in range(0,len(leer["@graph"])):
    try:
        print(leer["@graph"][i]["audience"])
        if leer["@graph"][i]["audience"] == "Niños":
            
        elif leer["@graph"][i]["audience"] == "Niños,Familias":
           
        print(leer["@graph"][i]["title"])
        print(leer["@graph"][i]["dtstart"])
        print(leer["@graph"][i]["dtend"])
        print(leer["@graph"][i]["link"])
    except Exception:
        print("")
# Out:
# ['hola']
#
#
#
# Niños,Familias
# Bambi
# 2017-10-30 18:00:00.0
# 2017-10-30 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c86f1fcc397ce510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Bebecuentos con Carlos Alba
# 2017-12-04 17:30:00.0
# 2017-12-04 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c1a0121bd69be510VgnVCM1000001d4a900aRCRD
#
#
#
#
#
#
#
# Niños,Familias
# Chap, chap, ...plash con Alicia Mohino
# 2017-11-20 17:30:00.0
# 2017-11-20 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=aa3c121bd69be510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Chap, chap, ...plash con Alicia Mohino
# 2017-11-13 17:30:00.0
# 2017-11-13 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=58cb121bd69be510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Chap, chap, ...plash con Alicia Mohino
# 2017-12-04 17:30:00.0
# 2017-12-04 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=3e9e121bd69be510VgnVCM1000001d4a900aRCRD
#
#
#
#
# Niños,Familias
# Cocinando cuentos con Primigenius
# 2017-11-06 17:30:00.0
# 2017-11-06 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=550c121bd69be510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Cocinando cuentos con Primigenius
# 2017-12-04 17:30:00.0
# 2017-12-04 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2cde121bd69be510VgnVCM1000001d4a900aRCRD
# Niños
# Cocinando cuentos con Primigenius
# 2017-11-07 18:00:00.0
# 2017-11-07 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b11fc686ebe0e510VgnVCM1000001d4a900aRCRD
# Niños
# Cocinando cuentos con Primigenius
# 2017-10-31 18:00:00.0
# 2017-10-31 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a7f3b6008fe0e510VgnVCM1000001d4a900aRCRD
# Niños
# Cocinando cuentos con Primigenius
# 2017-11-22 18:00:00.0
# 2017-11-22 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=f4e221dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# Cocinando cuentos con Primigenius
# 2017-11-17 18:00:00.0
# 2017-11-17 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=5e0b21dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# Cocinando cuentos con Primigenius
# 2017-10-19 18:00:00.0
# 2017-10-19 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8d2421dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# Cocinando cuentos con Primigenius
# 2017-12-01 18:00:00.0
# 2017-12-01 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=5208c686ebe0e510VgnVCM1000001d4a900aRCRD
# Niños
# Cocinando cuentos con Primigenius
# 2017-11-02 18:00:00.0
# 2017-11-02 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=10a498df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# Cocinando cuentos con Primigenius
# 2017-11-23 18:00:00.0
# 2017-11-23 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=70b8bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños
# CoderDojo
# 2017-10-08 09:30:00.0
# 2018-06-24 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=20da05b07f89e510VgnVCM1000001d4a900aRCRD
# Niños
# CoderDojo en la Biblioteca María Lejárraga
# 2017-10-21 12:00:00.0
# 2018-01-27 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6d91e313af00f510VgnVCM2000001f4a900aRCRD
#
#
#
# Niños
# Contando leones con Volvoreta
# 2017-10-19 18:00:00.0
# 2017-10-19 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=dea821dc4131e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Corazón de tinta
# 2017-10-24 18:00:00.0
# 2017-10-24 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=372305e0137ce510VgnVCM1000001d4a900aRCRD
#
# Niños
# Cuentos bufonescos con Juan Gamba
# 2017-11-21 18:00:00.0
# 2017-11-21 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=566fc686ebe0e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Cuentos bufonescos con Juan Gamba
# 2017-10-25 18:00:00.0
# 2017-10-25 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6046b6008fe0e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos bufonescos con Juan Gamba
# 2017-12-15 18:00:00.0
# 2017-12-15 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=42f098df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Cuentos bufonescos con Juan Gamba
# 2017-10-19 18:00:00.0
# 2017-10-19 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=f10298df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos bufonescos con Juan Gamba
# 2017-11-16 18:00:00.0
# 2017-11-16 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=cfd498df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos bufonescos con Juan Gamba
# 2017-12-17 12:00:00.0
# 2017-12-17 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=faaeab562631e510VgnVCM2000001f4a900aRCRD
# Niños
# Cuentos bufonescos con Juan Gamba
# 2017-10-31 18:00:00.0
# 2017-10-31 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a4df21dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos con Carlos Alba
# 2017-12-07 18:00:00.0
# 2017-12-07 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=7f45bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos de enredos y travesuras con Nelso Calderon
# 2017-11-19 12:00:00.0
# 2017-11-19 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=680eab562631e510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Cuentos de enredos y travesuras con Nelson Calderón
# 2017-11-03 18:00:00.0
# 2017-11-03 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c1adeeb6482ee510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos de enredos y travesuras con Nelson Calderón
# 2017-11-28 18:00:00.0
# 2017-11-28 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2051bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos de enredos y travesuras con Nelson Calderón
# 2017-11-16 18:00:00.0
# 2017-11-16 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=13724410571fe510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos de enredos y travesuras con Nelson Calderón
# 2017-12-14 18:00:00.0
# 2017-12-14 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=e8e298df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos de enredos y travesuras con Nelson Calderón
# 2017-10-25 18:00:00.0
# 2017-10-25 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c4a3562d96e0e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos de enredos y travesuras con Nelson Calderón
# 2017-11-02 18:00:00.0
# 2017-11-02 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=f69e98df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos de enredos y travesuras con Nelson Calderón
# 2017-11-21 18:00:00.0
# 2017-11-21 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ca41562d96e0e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos de enredos y travesuras con Nelson Calderón
# 2017-10-26 18:00:00.0
# 2017-10-26 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b54498df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos infantiles en la Biblioteca Pública Municipal La Chata
# 2017-11-24 18:00:00.0
# 2017-11-24 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8e6b21dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos infantiles en la Biblioteca Pública Municipal La Chata
# 2017-12-15 18:00:00.0
# 2017-12-15 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=13cb21dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos infantiles en la Biblioteca Pública Municipal La Chata
# 2017-10-27 18:00:00.0
# 2017-10-27 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=63da21dc4131e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Cuentos por las ramas con Alicia Mohíno
# 2017-11-14 17:30:00.0
# 2017-11-14 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=553d121bd69be510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Cuentos por las ramas con Alicia Mohíno
# 2017-11-06 17:30:00.0
# 2017-11-06 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=233d121bd69be510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos por las ramas con Alicia Mohino
# 2017-11-30 18:00:00.0
# 2017-11-30 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=9073c686ebe0e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos por las ramas con Alicia Mohino
# 2017-10-19 18:00:00.0
# 2017-10-19 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=df5e98df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos por las ramas con Alicia Mohino
# 2017-11-16 18:00:00.0
# 2017-11-16 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=f39298df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos por las ramas con Alicia Mohíno
# 2017-11-28 18:00:00.0
# 2017-11-28 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6f86bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños
# Cuentos por las ramas con Alicia Mohíno
# 2017-11-28 18:00:00.0
# 2017-11-28 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ec77b053322ee510VgnVCM2000001f4a900aRCRD
#
#
#
#
#
#
#
#
#
# Niños,Familias
# El dragón que se comió el Sol con Daniel Tornero
# 2017-12-04 18:00:00.0
# 2017-12-04 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c2a2bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños
# El dragón que se comió el Sol con Daniel Tornero
# 2017-10-31 18:00:00.0
# 2017-10-31 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=789d21dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# El dragón que se comió el Sol con Daniel Tornero
# 2017-12-13 18:00:00.0
# 2017-12-13 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8f2321dc4131e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# El dragón que se comió el sol con Daniel Tornero
# 2017-12-15 18:00:00.0
# 2017-12-15 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=99cdeeb6482ee510VgnVCM1000001d4a900aRCRD
# Niños
# El dragón que se comió el sol con Daniel Tornero
# 2017-10-20 18:00:00.0
# 2017-10-20 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=3666562d96e0e510VgnVCM1000001d4a900aRCRD
# Niños
# El dragón que se comió el Sol con Daniel Tornero
# 2017-11-21 18:00:00.0
# 2017-11-21 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d464bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños
# El dragón que se comió el Sol con Daniel Tornero
# 2017-11-22 18:00:00.0
# 2017-11-22 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=91cebc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños
# El dragón que se comió el Sol con Daniel Tornero
# 2017-12-12 18:00:00.0
# 2017-12-12 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=699021dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# El fantasma al que le asustaban los libros con Nelson Calderón
# 2017-11-24 18:00:00.0
# 2017-11-24 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=3833bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños
# El fantasma al que le asustaban los libros con Nelson Calderón
# 2017-10-19 18:00:00.0
# 2017-10-19 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a36721dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# El fantasma al que le asustaban los libros con Nelson Calderón
# 2017-10-20 18:00:00.0
# 2017-10-20 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=44aa21dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# El fantasma al que le asustaban los libros con Nelson Calderón
# 2017-12-01 18:00:00.0
# 2017-12-01 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=afa098df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# El fantasma al que le asustaban los libros con Nelson Calderón
# 2017-11-07 18:00:00.0
# 2017-11-07 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0236bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños
# El fantasma que asustaba a los cuentos con Nelson Calderón
# 2017-10-21 12:00:00.0
# 2017-10-21 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=da10ab562631e510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# El iglú
# 2017-10-26 18:00:00.0
# 2017-10-26 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=1d88440e22ece510VgnVCM2000001f4a900aRCRD
#
# Niños
# El león Kandina con Boniface ofogo
# 2017-12-14 18:00:00.0
# 2017-12-14 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=da84c686ebe0e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# El león Kandinga con Bonface Ofogo
# 2017-11-15 17:30:00.0
# 2017-11-15 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=63fc121bd69be510VgnVCM1000001d4a900aRCRD
# Niños
# El león Kandinga con Boniface
# 2017-11-03 18:00:00.0
# 2017-11-03 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=142098df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# El león Kandinga con Boniface
# 2017-11-02 18:00:00.0
# 2017-11-02 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a2e821dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# El león Kandinga con Boniface
# 2017-11-16 18:00:00.0
# 2017-11-16 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d7ce98df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# El león Kandinga con Boniface Ofogo
# 2017-10-26 18:00:00.0
# 2017-10-26 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a982c686ebe0e510VgnVCM1000001d4a900aRCRD
# Niños
# El león Kandinga con Boniface Ofogo
# 2017-12-12 18:00:00.0
# 2017-12-12 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a205bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# El león Kandinga con Boniface Ofogo
# 2017-10-27 18:00:00.0
# 2017-10-27 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a66f3aa2b8dce510VgnVCM1000001d4a900aRCRD
# Niños
# El león Kandinga con Boniface Ofogo
# 2017-11-28 18:00:00.0
# 2017-11-28 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=765e21dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# El león Kandinga con Boniface Ofogo
# 2017-12-02 12:00:00.0
# 2017-12-02 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=bbc0ab562631e510VgnVCM2000001f4a900aRCRD
# Niños
# El león Kandinga con Boniface Ofogo
# 2017-12-02 12:00:00.0
# 2017-12-02 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=cc6eab562631e510VgnVCM2000001f4a900aRCRD
# Niños
# El león Kandinga con Boniface Ofogo
# 2017-11-17 18:00:00.0
# 2017-11-17 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=4697562d96e0e510VgnVCM1000001d4a900aRCRD
# Niños
# El león Kandinga con Boniface Ofogo
# 2017-10-25 18:00:00.0
# 2017-10-25 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=5fc0b6008fe0e510VgnVCM1000001d4a900aRCRD
# Niños
# El león Kandinga con Boniface Ofogo
# 2017-11-14 18:00:00.0
# 2017-11-14 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=4121bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños
# El león Kandinga con Boniface Ofogo
# 2017-11-29 18:00:00.0
# 2017-11-29 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=5064562d96e0e510VgnVCM1000001d4a900aRCRD
# Niños
# El león Kandinga con Boniface Ofogo
# 2017-10-24 18:00:00.0
# 2017-10-24 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=538ec686ebe0e510VgnVCM1000001d4a900aRCRD
# Niños
# El león Kandinga con Boniface Ofogo
# 2017-12-05 18:00:00.0
# 2017-12-05 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b822562d96e0e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# El León Kandinga con Boniface Ofogo
# 2017-10-26 18:00:00.0
# 2017-10-26 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=643298df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# El león Kandinga con Boniface Ofogo
# 2017-11-30 18:00:00.0
# 2017-11-30 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=4a18bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# El lobo que se cayó de un libro
# 2017-10-25 18:00:00.0
# 2017-10-25 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6bf8f6a3338ce510VgnVCM1000001d4a900aRCRD
#
# Niños
# El pequeño país con Victoria
# 2017-11-16 18:00:00.0
# 2017-11-16 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=24f2c686ebe0e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# El pequeño país con Victoria
# 2017-11-30 18:00:00.0
# 2017-11-30 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ee1ac686ebe0e510VgnVCM1000001d4a900aRCRD
# Niños
# El pequeño país con Victoria
# 2017-10-26 18:00:00.0
# 2017-10-26 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=81d721dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# El pequeño país con Victoria
# 2017-11-14 18:00:00.0
# 2017-11-14 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=93dd21dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# El pequeño país con Victoria
# 2017-11-15 18:00:00.0
# 2017-11-15 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=caa6b6008fe0e510VgnVCM1000001d4a900aRCRD
# Niños
# El pequeño país con Victoria
# 2017-10-28 12:00:00.0
# 2017-10-28 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=802fab562631e510VgnVCM2000001f4a900aRCRD
# Niños
# El pequeño país con Victoria
# 2017-11-25 12:00:00.0
# 2017-11-25 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2e4fab562631e510VgnVCM2000001f4a900aRCRD
# Niños
# El pequeño país con Victoria
# 2017-11-23 18:00:00.0
# 2017-11-23 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8ca421dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# El pequeño país con Victoria
# 2017-11-17 18:00:00.0
# 2017-11-17 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=465098df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# El pequeño país con Victoria
# 2017-12-01 18:00:00.0
# 2017-12-01 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=97cdeeb6482ee510VgnVCM1000001d4a900aRCRD
# Niños
# El pequeño país con Victoria
# 2017-12-16 12:00:00.0
# 2017-12-16 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2e01ab562631e510VgnVCM2000001f4a900aRCRD
# Niños
# El pequeño país con Victoria
# 2017-11-02 18:00:00.0
# 2017-11-02 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=736298df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# El pequeño país con Victoria
# 2017-11-03 18:00:00.0
# 2017-11-03 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b797562d96e0e510VgnVCM1000001d4a900aRCRD
# Niños
# El pequeño país con Victoria
# 2017-12-14 18:00:00.0
# 2017-12-14 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d11598df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# El pequeño país con Victoria
# 2017-12-12 18:00:00.0
# 2017-12-12 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=16c6bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños
# El pequeño país con Victoria
# 2017-12-13 18:00:00.0
# 2017-12-13 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=953fbc1fc431e510VgnVCM1000001d4a900aRCRD
#
#
# Niños,Familias
# El viaje de Arlo
# 2017-10-19 18:00:00.0
# 2017-10-19 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c982259bcecbe510VgnVCM1000001d4a900aRCRD
#
#
#
# Niños
# Especial Día de Halloween
# 2017-10-31 18:00:00.0
# 2017-10-31 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2c5b7a206c9ae510VgnVCM1000001d4a900aRCRD
# Niños
# Especial Día de la Biblioteca
# 2017-10-24 18:00:00.0
# 2017-10-24 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a4aa7a206c9ae510VgnVCM1000001d4a900aRCRD
#
#
#
# Niños,Familias
# Gloriadías en el Día de la Biblioteca
# 2017-10-24 18:00:00.0
# 2017-10-24 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a95e9bd281cde510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Heroes Comic Con en Biblioteca Buenavista
# 2017-11-22 18:00:00.0
# 2017-11-22 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8d7e88aef110f510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Heroes Comic Con en Biblioteca Gerardo Diego
# 2017-11-17 18:00:00.0
# 2017-11-17 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=802b88aef110f510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Heroes Comic Con en Biblioteca Miguel Delibes
# 2017-11-08 17:30:00.0
# 2017-11-08 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0751e04c3400f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Heroes Comic Con en Biblioteca Moratalaz
# 2017-10-20 17:30:00.0
# 2017-10-20 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=eddfe04c3400f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Heroes Comic Con en Biblioteca Vargas LLosa
# 2017-11-24 18:00:00.0
# 2017-11-24 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=843f88aef110f510VgnVCM1000001d4a900aRCRD
#
# Niños,Familias
# Hora del cuento en la Biblioteca Gloria Fuertes
# 2017-10-18 18:00:00.0
# 2018-06-20 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=26c6b963436ee510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Hotel Transilvania 2
# 2017-10-31 19:00:00.0
# 2017-10-31 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=1f081fcc397ce510VgnVCM2000001f4a900aRCRD
#
# Niños
# La casa de Tomasa y otras historias con Daniel Tornero
# 2017-11-29 18:00:00.0
# 2017-11-29 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=bff0b6008fe0e510VgnVCM1000001d4a900aRCRD
# Niños
# La casa de Tomasa y otras historias con Daniel Tornero
# 2017-11-28 18:00:00.0
# 2017-11-28 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=3b74b6008fe0e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# La Casa Encantada
# 2017-10-31 18:00:00.0
# 2017-10-31 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=c023f6a3338ce510VgnVCM1000001d4a900aRCRD
#
#
#
# Niños,Familias
# La Panditeca
# 2017-10-02 18:00:00.0
# 2017-12-18 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d3f9fc25b365e510VgnVCM2000001f4a900aRCRD
#
#
# Niños,Familias
# Labyrinth con Face2face
# 2017-11-17 18:00:00.0
# 2017-11-17 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=5b7feeb6482ee510VgnVCM1000001d4a900aRCRD
# Niños
# Labyrinth con Face2face
# 2017-11-04 12:00:00.0
# 2017-11-04 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=7650ab562631e510VgnVCM2000001f4a900aRCRD
# Niños
# Labyrinth con Face2face
# 2017-11-22 18:00:00.0
# 2017-11-22 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=10f6b6008fe0e510VgnVCM1000001d4a900aRCRD
# Niños
# Labyrinth con Face2Face
# 2017-11-30 18:00:00.0
# 2017-11-30 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=13b4bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Las gallinas contadoras con Volvoreta
# 2017-11-15 17:30:00.0
# 2017-11-15 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=f45b121bd69be510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Las gallinas contadoras con Volvoreta
# 2017-11-16 17:30:00.0
# 2017-11-16 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0fe3f500d625e510VgnVCM2000001f4a900aRCRD
#
# Niños
# Los superescritores
# 2017-09-03 18:15:00.0
# 2017-12-19 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ebb006483206e510VgnVCM1000001d4a900aRCRD
#
#
#
# Niños
# Makers Unite. Juguetrónica infantil
# 2017-12-04 18:00:00.0
# 2017-12-04 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=fd1024812658e510VgnVCM1000001d4a900aRCRD
# Niños
# Makers Unite. Juguetrónica infantil
# 2017-11-13 18:00:00.0
# 2017-11-13 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=61ef24812658e510VgnVCM1000001d4a900aRCRD
# Niños
# Makers Unite. Juguetrónica infantil
# 2017-10-23 17:30:00.0
# 2017-10-23 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=40bf24812658e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Maratón de cuentos
# 2017-10-24 18:00:00.0
# 2017-10-24 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6169cc89e6a1b510VgnVCM1000001d4a900aRCRD
#
# Niños
# Mi diario con Cuarta Pared
# 2017-12-14 18:00:00.0
# 2017-12-14 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=770f98df8ed0e510VgnVCM1000001d4a900aRCRD
#
#
#
# Niños
# Perdidos en el belén con Alicia Mohino
# 2017-12-05 18:00:00.0
# 2017-12-05 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=36bfc686ebe0e510VgnVCM1000001d4a900aRCRD
#
#
#
#
# Niños,Familias
# Ratones de bibliotecas con Volvoreta
# 2017-12-14 17:30:00.0
# 2017-12-14 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=77f3f500d625e510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Ratones de bibliotecas con Volvoreta
# 2017-12-13 17:30:00.0
# 2017-12-13 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0f0e121bd69be510VgnVCM1000001d4a900aRCRD
#
#
#
#
#
#
#
# Mujeres
# Sexualidad para mujeres.
# 2017-12-04 19:00:00.0
# 2017-12-18 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0a40ddacea99e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Snowball con Face2face
# 2017-10-19 18:00:00.0
# 2017-10-19 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2699c686ebe0e510VgnVCM1000001d4a900aRCRD
# Niños
# Snowball con Face2face
# 2017-10-27 18:00:00.0
# 2017-10-27 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=1213bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Snowball con Face2face
# 2017-10-30 18:00:00.0
# 2017-10-30 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=e232bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños
# Snowball con Face2face
# 2017-11-14 18:00:00.0
# 2017-11-14 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=9744b6008fe0e510VgnVCM1000001d4a900aRCRD
# Niños
# Snowball con Face2Face
# 2017-10-20 18:00:00.0
# 2017-10-20 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=dcef98df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# SnowBall con Face2Face
# 2017-10-26 18:00:00.0
# 2017-10-26 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=856421dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# Snowball con Face2face
# 2017-11-18 12:00:00.0
# 2017-11-18 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=7d80ab562631e510VgnVCM2000001f4a900aRCRD
# Niños
# Snowball con Face2face
# 2017-10-22 12:00:00.0
# 2017-10-22 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=4f8dab562631e510VgnVCM2000001f4a900aRCRD
# Niños
# Snowball con Face2Face
# 2017-10-24 18:00:00.0
# 2017-10-24 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d206bc1fc431e510VgnVCM1000001d4a900aRCRD
#
#
#
#
# Niños
# Taller de Halloween
# 2017-10-30 18:00:00.0
# 2017-10-30 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=ecc3e52ec152f510VgnVCM2000001f4a900aRCRD
# Niños
# Taller de Halloween
# 2017-10-30 18:00:00.0
# 2017-10-30 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=85a6437904f2f510VgnVCM2000001f4a900aRCRD
#
#
#
#
# Familias
# Taller de prevención del bullying
# 2017-11-24 17:00:00.0
# 2017-11-24 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8db889d1f1c0f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Taller Heroes Comic Con en Biblioteca Aluche
# 2017-11-22 18:00:00.0
# 2017-11-22 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=67ff386e9c10f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Taller Heroes Comic Con en Biblioteca Aluche
# 2017-11-24 18:00:00.0
# 2017-11-24 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0420386e9c10f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Taller Heroes Comic Con en Biblioteca Ángel González
# 2017-10-20 18:00:00.0
# 2017-10-20 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d5fb386e9c10f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Taller Heroes Comic Con en Biblioteca Ángel González
# 2017-10-25 18:00:00.0
# 2017-10-25 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=88dc386e9c10f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Taller Heroes Comic Con en Biblioteca Ángel González
# 2017-10-27 18:00:00.0
# 2017-10-27 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=381d386e9c10f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Taller Heroes Comic Con en Biblioteca Gabriel García Márquez
# 2017-11-08 17:30:00.0
# 2017-11-08 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=230e386e9c10f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Taller Heroes Comic Con en Biblioteca Gabriel García Márquez
# 2017-11-15 17:30:00.0
# 2017-11-15 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=081f386e9c10f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Taller Heroes Comic Con en Biblioteca José Hierro
# 2017-11-03 18:00:00.0
# 2017-11-03 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=e28d386e9c10f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Taller Heroes Comic Con en Biblioteca José Hierro
# 2017-11-10 18:00:00.0
# 2017-11-10 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8d4e386e9c10f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Taller Heroes Comic Con en Biblioteca José Saramago
# 2017-10-25 18:00:00.0
# 2017-10-25 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=0afc386e9c10f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Taller Heroes Comic Con en Biblioteca Mario Vargas Llosa
# 2017-11-10 18:00:00.0
# 2017-11-10 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a6be386e9c10f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Taller Heroes Comic Con en Biblioteca Miguel Delibes
# 2017-11-03 18:00:00.0
# 2017-11-03 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=6cad386e9c10f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Taller Heroes Comic Con en Biblioteca Miguel Delibes
# 2017-10-27 18:00:00.0
# 2017-10-27 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=5d3d386e9c10f510VgnVCM2000001f4a900aRCRD
# Niños,Familias
# Taller Heroes Comic Con en Biblioteca Miguel Delibes
# 2017-10-20 18:00:00.0
# 2017-10-20 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=188c386e9c10f510VgnVCM2000001f4a900aRCRD
#
# Niños
# Tan diferentes y tan iguales
# 2017-12-12 18:00:00.0
# 2017-12-12 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=4f9e21dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# Tan diferentes y tan iguales con Nelson Calderón
# 2017-12-05 18:00:00.0
# 2017-12-05 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a5c4b6008fe0e510VgnVCM1000001d4a900aRCRD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Niños
# Tiña Periña con Roberto Mezquita
# 2017-12-05 18:00:00.0
# 2017-12-05 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=7f71bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños
# Tiña Periña con Roberto Mezquita
# 2017-10-25 18:00:00.0
# 2017-10-25 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=dc8221dc4131e510VgnVCM1000001d4a900aRCRD
# Niños
# Tiña periña con Roberto Mezquita
# 2017-11-04 12:00:00.0
# 2017-11-04 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=9bcdab562631e510VgnVCM2000001f4a900aRCRD
# Niños
# Tiña Periña con Roberto Mezquita
# 2017-12-15 18:00:00.0
# 2017-12-15 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=2b68c686ebe0e510VgnVCM1000001d4a900aRCRD
# Niños
# Tiña Periña con Roberto Mezquita
# 2017-10-19 18:00:00.0
# 2017-10-19 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b5f398df8ed0e510VgnVCM1000001d4a900aRCRD
# Niños
# Tiña Periña con Roberto Mezquita
# 2017-10-30 18:00:00.0
# 2017-10-30 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d80621dc4131e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Tiña Periña con Roberto Mezquita
# 2017-11-27 18:00:00.0
# 2017-11-27 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=8c62bc1fc431e510VgnVCM1000001d4a900aRCRD
# Niños
# Tiña Periña con Roberto Mezquita
# 2017-11-23 18:00:00.0
# 2017-11-23 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=a46921dc4131e510VgnVCM1000001d4a900aRCRD
# Niños,Familias
# Un viaje de colores
# 2017-11-02 18:00:00.0
# 2017-11-02 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=b69ba7fcd7a0f510VgnVCM2000001f4a900aRCRD
#
# Niños
# Una fiera en mi pecera. Para niños de 3 a 6 años
# 2017-10-25 18:00:00.0
# 2017-10-25 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=d77f2431247eb510VgnVCM1000001d4a900aRCRD
# Niños
# Una ilustración de cuento
# 2017-10-02 00:00:00.0
# 2017-10-27 23:59:00.0
# http://www.madrid.es/sites/v/index.jsp?vgnextchannel=1ccd566813946010VgnVCM100000dc0ca8c0RCRD&vgnextoid=cd3fa4eda88ce510VgnVCM1000001d4a900aRCRD

# %% [raw]
# import math
#
# def haversine(lat1, lon1, lat2, lon2):
#     rad=math.pi/180
#     dlat=lat2-lat1
#     dlon=lon2-lon1
#     R=6372.795477598
#     a=(math.sin(rad*dlat/2))**2 + math.cos(rad*lat1)*math.cos(rad*lat2)*(math.sin(rad*dlon/2))**2
#     distancia=2*R*math.asin(math.sqrt(a))
#     return distancia

# %% [markdown]
# Para leer los archivos usa un código como el siguiente:

# %% [raw]
# import json
# leer = json.loads(open('Agenda.json',encoding="utf8").read())

# %% [markdown]
# #### Normas de entrega
#
# * Fecha tope de entrega: 27/10/2017
# * La entrega se realizará subiendo al campus virtual un notebook de Jupyter con la solución. El archivo tendrá como nombre FormatosI_GrupoX donde X será el número de grupo correspondiente.
